# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">

# %% [markdown]
# # Python & AI for Algorithmic Trading
# ## Chapter 22 · Conclusions and Outlook
#
# &copy; Dr. Yves J. Hilpisch<br>
# AI-Powered by GPT 5.1<br>
# The Python Quants GmbH | https://tpq.io<br>
# https://hilpisch.com | https://linktr.ee/dyjh

# %% [markdown]
# ### Notebook Goals
#
# This notebook turns the concluding discussion into a concrete learning-plan artifact.
#
# - Build a small `LearningPlan` with tasks across data, backtesting, risk, and AI.
# - Serialise the plan to JSON and save it under `reports/`.
# - Inspect the structured representation to guide personal next steps.

# %%
import sys
from pathlib import Path
import subprocess
if "google.colab" in sys.modules:
    REPO_URL = "https://github.com/yhilpisch/paatcode.git"
    ROOT_DIR = Path("/content/paatcode")
    if not ROOT_DIR.exists():
        subprocess.run([
            "git",
            "clone",
            REPO_URL,
            str(ROOT_DIR),
        ], check=True)
    PROJECT_ROOT = ROOT_DIR
else:
    PROJECT_ROOT = Path("..").resolve()  # project root relative to notebooks
CODE_DIR = PROJECT_ROOT / "code"  # folder with chapter scripts
if str(CODE_DIR) not in sys.path:  # ensure scripts are importable
    sys.path.insert(0, str(CODE_DIR))

import ch22_conclusions_outlook as ch22  # learning-plan helpers

# %% [markdown]
# ### 1. Example Learning Plan
#
# We start from the demo plan provided in the script and inspect its tasks.

# %%
plan = ch22.demo_plan()
[(t.area, t.description, t.estimated_hours, t.priority) for t in plan.tasks]

# %% [markdown]
# ### 2. Persisting the Plan
#
# We serialise the plan to JSON so that it can live alongside notebooks, configuration, and code.

# %%
out_path = PROJECT_ROOT / "reports" / "learning_plan_pyaialgo.json"
plan.save(out_path)
out_path

# %% [markdown]
# ### Takeaways
#
# - Treating the conclusions as an explicit plan keeps the material actionable.
# - Small JSON files make it easy to track progress and adjust priorities over time.
# - You can extend the `LearningPlan` structure with your own categories, such as tooling, case studies, or automation projects.

# %% [markdown]
# <img src="https://hilpisch.com/tpq_logo_bic.png" width="20%" align="right">
